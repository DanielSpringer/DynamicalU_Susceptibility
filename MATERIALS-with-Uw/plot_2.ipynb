# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

beta = 50
PATH = "/mnt/scratch/daniel/Data/DynamicalU_Susceptibility/MATERIALS-with-Uw/"

fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(20,10))
c = 0
r = 0
with h5py.File(PATH+"data_collection.h5", "r") as f:
    for n, ff in enumerate(f.keys()):
        for o in range(1):
            ax[r,c].plot(f[ff]["w"][:], f[ff]["Aw/"+str(o)][:].real, linewidth="2")
        ax[r,c].set_title(ff)
        c += 1
        if c == 3:
            r += 1
            c = 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 15
#      12 for n, ff in enumerate(f.keys()):
#      14     for o in range(1):
# ---> 15         ax[r,c].plot(f[ff]["w"], f[ff]["Aw/"+str(o)][:].real, linewidth="2")
#      16     ax[r,c].set_title(ff)
#      17     c += 1
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/XInstalls/anaconda3/envs/maxent/lib/python3.9/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:241, in h5py.h5o.open()
#
# KeyError: "Unable to open object (object 'w' doesn't exist)"
